# %% [markdown]
# 🚀 Project Description
#
# High-Performance LoRA Fusion & Compression for Large-Scale LLMs (Nemotron 30B)
#
# This project presents an advanced pipeline for merging and optimizing Low-Rank Adaptation (LoRA) weights for large language models. It introduces a custom patching mechanism to override internal adapter fusion behavior and applies Singular Value Decomposition (SVD) to compress merged LoRA matrices into a fixed low-rank representation.
#
# Designed for large-scale models such as NVIDIA Nemotron 30B, this approach significantly improves efficiency while maintaining performance by enforcing a consistent rank constraint across fused projections.
#
#
# ---
#
# 🔧 Key Features
#
# Custom LoRA Fusion Logic
# Overrides default fused projection merging with a fully controlled implementation.
#
# SVD-Based Rank Compression
# Reduces merged LoRA weights to a fixed rank (e.g., 32) using optimal low-rank approximation.
#
# Memory-Efficient Processing
# Minimizes parameter overhead for large models without sacrificing representational quality.
#
# Seamless Integration
# Works with the tinker-cookbook framework and supports adapter-based workflows.
#
# Production-Ready Output
# Automatically builds and exports a deployable adapter package (ZIP format).
#
#
#
# ---
#
# 🧠 Technical Overview
#
# The pipeline:
#
# 1. Collects multiple LoRA components from fused projections
#
#
# 2. Merges them into unified matrices
#
#
# 3. Applies SVD decomposition to compute the best low-rank approximation
#
#
# 4. Reconstructs compressed LoRA weights
#
#
# 5. Injects them back into the model using a patched adapter mechanism
#
#
#
# This ensures both efficiency and scalability when working with multi-billion parameter models.
#
#
# ---
#
# 🎯 Use Cases
#
# Optimizing LoRA adapters for large language models
#
# Reducing memory footprint in LLM fine-tuning
#
# Preparing efficient submission artifacts (e.g., Kaggle competitions)
#
# Building scalable AI systems with adapter-based architectures
#
#
#
# ---
#
# ⚠️ Requirements
#
# PyTorch (with GPU recommended)
#
# High-memory environment (for 30B models)
#
# tinker-cookbook (installed via GitHub)
#
#
#
# ---
#
# 💡 Why This Matters
#
# As LLMs grow larger, efficient adaptation methods like LoRA become critical. This project goes beyond standard usage by introducing custom fusion control + mathematical compression, enabling faster, lighter, and more scalable AI systems.

# %%
# !uv pip install --no-cache-dir --force-reinstall "tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinker-cookbook.git@nightly"
# Out:
# Using Python 3.12.12 environment at: /usr
#    Updating https://github.com/thinking-machines-lab/tinker-cookbook.git (nightl
#    Updating https://github.com/thinking-machines-lab/tinker-cookbook.git (nightl
#    Updating https://github.com/thinking-machines-lab/tinker-cookbook.git (nightl
#    Updating https://github.com/thinking-machines-lab/tinker-cookbook.git (nightl
#    Updating https://github.com/thinking-machines-lab/tinker-cookbook.git (nightl
#    Updating https://github.com/thinking-machines-lab/tinker-cookbook.git (nightl
#    Updating https://github.com/thinking-machines-lab/tinker-cookbook.git (nightl
#    Updating https://github.com/thinking-machines-lab/tinker-cookbook.git (nightl
#    Updating https://github.com/thinking-machines-lab/tinker-cookbook.git (nightl
#    Updating https://github.com/thinking-machines-lab/tinker-cookbook.git (nightl
#    Updating https://github.com/thinking-machines-lab/tinker-cookbook.git (nightl
#    Updating https://github.com/thinking-machines-lab/tinker-cookbook.git (nightl
#     Updated https://github.com/thinking-machines-lab/tinker-cookbook.git (dacb83
# Resolved 93 packages in 5.23s
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# hf-xet               ------------------------------     0 B/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# protobuf             ------------------------------     0 B/316.67 KiB
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# protobuf             ------------------------------ 14.83 KiB/316.67 KiB
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# protobuf             ------------------------------ 14.83 KiB/316.67 KiB
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# protobuf             ------------------------------ 14.83 KiB/316.67 KiB
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# protobuf             ------------------------------ 14.83 KiB/316.67 KiB
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# protobuf             ------------------------------ 14.83 KiB/316.67 KiB
# pyyaml               ------------------------------     0 B/788.94 KiB
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# protobuf             ------------------------------ 14.83 KiB/316.67 KiB
# pyyaml               ------------------------------     0 B/788.94 KiB
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# protobuf             ------------------------------ 14.83 KiB/316.67 KiB
# pyyaml               ------------------------------     0 B/788.94 KiB
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# protobuf             ------------------------------ 14.83 KiB/316.67 KiB
# pyyaml               ------------------------------     0 B/788.94 KiB
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# protobuf             ------------------------------ 14.83 KiB/316.67 KiB
# pyyaml               ------------------------------     0 B/788.94 KiB
# hf-xet               ------------------------------ 14.80 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# fsspec                 ------------------------------ 62.84 KiB/197.76 KiB
# tinker                 ------------------------------ 41.46 KiB/205.18 KiB
# charset-normalizer     ------------------------------ 76.05 KiB/211.51 KiB
# propcache              ------------------------------ 32.00 KiB/216.38 KiB
# python-dateutil        ------------------------------ 75.95 KiB/224.50 KiB
# frozenlist             ------------------------------     0 B/236.73 KiB
# multidict              ------------------------------ 76.81 KiB/250.31 KiB
# rich                   ------------------------------ 75.79 KiB/303.37 KiB
# protobuf               ------------------------------ 77.80 KiB/316.67 KiB
# pydantic               ------------------------------ 75.32 KiB/460.92 KiB
# safetensors            ------------------------------ 92.91 KiB/495.27 KiB
# mpmath                 ------------------------------     0 B/523.63 KiB
# huggingface-hub        ------------------------------ 90.88 KiB/645.16 KiB
# pyyaml                 ------------------------------ 91.35 KiB/788.94 KiB
# nvidia-cufile          ------------------------------     0 B/1.17 MiB
# pygments               ------------------------------ 74.89 KiB/1.17 MiB
# networkx               ------------------------------ 66.26 KiB/1.97 MiB
# pydantic-core          ------------------------------ 77.33 KiB/2.00 MiB
# hf-xet                 ------------------------------ 94.57 KiB/4.02 MiB
# lxml                   ------------------------------ 62.99 KiB/5.00 MiB
# sympy                  ------------------------------ 72.88 KiB/6.01 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# xxhash                 ------------------------------ 30.84 KiB/189.39 KiB
# fsspec                 ------------------------------ 110.84 KiB/197.76 KiB
# tinker                 ------------------------------ 78.81 KiB/205.18 KiB
# charset-normalizer     ------------------------------ 124.05 KiB/211.51 KiB
# propcache              ------------------------------ 80.00 KiB/216.38 KiB
# python-dateutil        ------------------------------ 123.95 KiB/224.50 KiB
# frozenlist             ------------------------------     0 B/236.73 KiB
# multidict              ------------------------------ 124.81 KiB/250.31 KiB
# rich                   ------------------------------ 139.79 KiB/303.37 KiB
# protobuf               ------------------------------ 98.33 KiB/316.67 KiB
# pydantic               ------------------------------ 123.32 KiB/460.92 KiB
# safetensors            ------------------------------ 140.91 KiB/495.27 KiB
# datasets               ------------------------------     0 B/516.58 KiB
# mpmath                 ------------------------------ 32.00 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 138.88 KiB/645.16 KiB
# regex                  ------------------------------ 1.87 KiB/782.35 KiB
# pyyaml                 ------------------------------ 139.25 KiB/788.94 KiB
# setuptools             ------------------------------ 46.80 KiB/1.01 MiB
# tiktoken               ------------------------------     0 B/1.10 MiB
# nvidia-cufile          ------------------------------ 46.83 KiB/1.17 MiB
# pygments               ------------------------------ 122.89 KiB/1.17 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠙ Preparing packages... (0/93)
# xxhash                 ------------------------------ 78.84 KiB/189.39 KiB
# fsspec                 ------------------------------ 142.84 KiB/197.76 KiB
# tinker                 ------------------------------ 126.81 KiB/205.18 KiB
# charset-normalizer     ------------------------------ 172.05 KiB/211.51 KiB
# propcache              ------------------------------ 118.99 KiB/216.38 KiB
# python-dateutil        ------------------------------ 155.95 KiB/224.50 KiB
# frozenlist             ------------------------------ 47.63 KiB/236.73 KiB
# multidict              ------------------------------ 156.81 KiB/250.31 KiB
# rich                   ------------------------------ 171.79 KiB/303.37 KiB
# protobuf               ------------------------------ 139.43 KiB/316.67 KiB
# pydantic               ------------------------------ 139.32 KiB/460.92 KiB
# safetensors            ------------------------------ 172.91 KiB/495.27 KiB
# datasets               ------------------------------ 46.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 78.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 170.88 KiB/645.16 KiB
# regex                  ------------------------------ 46.73 KiB/782.35 KiB
# pyyaml                 ------------------------------ 155.35 KiB/788.94 KiB
# setuptools             ------------------------------ 78.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 46.73 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 94.83 KiB/1.17 MiB
# pygments               ------------------------------ 154.89 KiB/1.17 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠹ Preparing packages... (1/93)
# xxhash                 ------------------------------ 110.84 KiB/189.39 KiB
# fsspec                 ------------------------------ 190.84 KiB/197.76 KiB
# tinker                 ------------------------------ 174.81 KiB/205.18 KiB
# charset-normalizer     ------------------------------ 211.51 KiB/211.51 KiB
# propcache              ------------------------------ 144.00 KiB/216.38 KiB
# python-dateutil        ------------------------------ 203.95 KiB/224.50 KiB
# frozenlist             ------------------------------ 92.73 KiB/236.73 KiB
# multidict              ------------------------------ 204.81 KiB/250.31 KiB
# rich                   ------------------------------ 219.79 KiB/303.37 KiB
# protobuf               ------------------------------ 171.43 KiB/316.67 KiB
# pydantic               ------------------------------ 187.32 KiB/460.92 KiB
# safetensors            ------------------------------ 220.91 KiB/495.27 KiB
# datasets               ------------------------------ 78.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 126.35 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 218.88 KiB/645.16 KiB
# regex                  ------------------------------ 78.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 188.00 KiB/788.94 KiB
# setuptools             ------------------------------ 126.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 78.73 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 142.83 KiB/1.17 MiB
# pygments               ------------------------------ 202.89 KiB/1.17 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠹ Preparing packages... (1/93)
# xxhash                 ------------------------------ 126.84 KiB/189.39 KiB
# fsspec                 ------------------------------ 190.84 KiB/197.76 KiB
# tinker                 ------------------------------ 174.81 KiB/205.18 KiB
# propcache              ------------------------------ 149.65 KiB/216.38 KiB
# python-dateutil        ------------------------------ 203.95 KiB/224.50 KiB
# frozenlist             ------------------------------ 92.73 KiB/236.73 KiB
# multidict              ------------------------------ 204.81 KiB/250.31 KiB
# rich                   ------------------------------ 219.79 KiB/303.37 KiB
# protobuf               ------------------------------ 171.43 KiB/316.67 KiB
# pydantic               ------------------------------ 187.32 KiB/460.92 KiB
# safetensors            ------------------------------ 220.91 KiB/495.27 KiB
# datasets               ------------------------------ 94.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 126.35 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 218.88 KiB/645.16 KiB
# regex                  ------------------------------ 78.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 188.00 KiB/788.94 KiB
# setuptools             ------------------------------ 126.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 78.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 142.83 KiB/1.17 MiB
# pygments               ------------------------------ 202.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 78.83 KiB/1.69 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠹ Preparing packages... (1/93)
# xxhash                 ------------------------------ 126.84 KiB/189.39 KiB
# tinker                 ------------------------------ 174.81 KiB/205.18 KiB
# propcache              ------------------------------ 149.65 KiB/216.38 KiB
# python-dateutil        ------------------------------ 219.95 KiB/224.50 KiB
# frozenlist             ------------------------------ 92.73 KiB/236.73 KiB
# multidict              ------------------------------ 220.81 KiB/250.31 KiB
# rich                   ------------------------------ 235.79 KiB/303.37 KiB
# protobuf               ------------------------------ 187.43 KiB/316.67 KiB
# pydantic               ------------------------------ 196.29 KiB/460.92 KiB
# safetensors            ------------------------------ 236.91 KiB/495.27 KiB
# datasets               ------------------------------ 94.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 126.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 234.88 KiB/645.16 KiB
# regex                  ------------------------------ 94.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 203.35 KiB/788.94 KiB
# setuptools             ------------------------------ 142.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 78.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 142.83 KiB/1.17 MiB
# pygments               ------------------------------ 202.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 78.83 KiB/1.69 MiB
# networkx               ------------------------------ 190.96 KiB/1.97 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠹ Preparing packages... (1/93)
# xxhash                 ------------------------------ 142.84 KiB/189.39 KiB
# tinker                 ------------------------------ 190.81 KiB/205.18 KiB
# propcache              ------------------------------ 165.65 KiB/216.38 KiB
# frozenlist             ------------------------------ 108.73 KiB/236.73 KiB
# multidict              ------------------------------ 236.81 KiB/250.31 KiB
# rich                   ------------------------------ 235.79 KiB/303.37 KiB
# protobuf               ------------------------------ 203.43 KiB/316.67 KiB
# pydantic               ------------------------------ 203.32 KiB/460.92 KiB
# safetensors            ------------------------------ 236.91 KiB/495.27 KiB
# datasets               ------------------------------ 110.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 126.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 250.88 KiB/645.16 KiB
# regex                  ------------------------------ 94.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 203.35 KiB/788.94 KiB
# setuptools             ------------------------------ 158.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 94.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 158.83 KiB/1.17 MiB
# pygments               ------------------------------ 218.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 94.83 KiB/1.69 MiB
# networkx               ------------------------------ 190.96 KiB/1.97 MiB
# pydantic-core          ------------------------------ 205.00 KiB/2.00 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠹ Preparing packages... (1/93)
# xxhash                 ------------------------------ 142.84 KiB/189.39 KiB
# propcache              ------------------------------ 165.65 KiB/216.38 KiB
# frozenlist             ------------------------------ 124.73 KiB/236.73 KiB
# multidict              ------------------------------ 236.81 KiB/250.31 KiB
# rich                   ------------------------------ 240.08 KiB/303.37 KiB
# protobuf               ------------------------------ 203.43 KiB/316.67 KiB
# pydantic               ------------------------------ 203.32 KiB/460.92 KiB
# safetensors            ------------------------------ 252.91 KiB/495.27 KiB
# datasets               ------------------------------ 110.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 142.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 250.88 KiB/645.16 KiB
# regex                  ------------------------------ 110.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 219.35 KiB/788.94 KiB
# setuptools             ------------------------------ 158.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 94.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 174.57 KiB/1.17 MiB
# pygments               ------------------------------ 218.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 94.83 KiB/1.69 MiB
# networkx               ------------------------------ 206.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 205.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 94.72 KiB/2.14 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠹ Preparing packages... (1/93)
# xxhash                 ------------------------------ 158.84 KiB/189.39 KiB
# propcache              ------------------------------ 181.65 KiB/216.38 KiB
# frozenlist             ------------------------------ 124.73 KiB/236.73 KiB
# rich                   ------------------------------ 255.79 KiB/303.37 KiB
# protobuf               ------------------------------ 219.43 KiB/316.67 KiB
# pydantic               ------------------------------ 219.32 KiB/460.92 KiB
# safetensors            ------------------------------ 268.91 KiB/495.27 KiB
# datasets               ------------------------------ 126.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 158.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 254.88 KiB/645.16 KiB
# regex                  ------------------------------ 126.73 KiB/782.35 KiB
# pyyaml                 ------------------------------ 235.35 KiB/788.94 KiB
# setuptools             ------------------------------ 174.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 110.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 174.57 KiB/1.17 MiB
# pygments               ------------------------------ 234.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 110.73 KiB/1.69 MiB
# networkx               ------------------------------ 222.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 221.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 110.72 KiB/2.14 MiB
# pycryptodomex          ------------------------------ 110.79 KiB/2.17 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠹ Preparing packages... (1/93)
# xxhash                 ------------------------------ 158.84 KiB/189.39 KiB
# propcache              ------------------------------ 192.00 KiB/216.38 KiB
# frozenlist             ------------------------------ 125.93 KiB/236.73 KiB
# rich                   ------------------------------ 255.79 KiB/303.37 KiB
# protobuf               ------------------------------ 235.43 KiB/316.67 KiB
# pydantic               ------------------------------ 219.32 KiB/460.92 KiB
# safetensors            ------------------------------ 268.91 KiB/495.27 KiB
# datasets               ------------------------------ 142.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 158.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 254.88 KiB/645.16 KiB
# regex                  ------------------------------ 126.73 KiB/782.35 KiB
# pyyaml                 ------------------------------ 235.35 KiB/788.94 KiB
# setuptools             ------------------------------ 174.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 110.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 190.57 KiB/1.17 MiB
# pygments               ------------------------------ 250.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 126.73 KiB/1.69 MiB
# networkx               ------------------------------ 222.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 221.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 126.72 KiB/2.14 MiB
# pycryptodomex          ------------------------------ 110.79 KiB/2.17 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠹ Preparing packages... (1/93)
# propcache              ------------------------------ 208.00 KiB/216.38 KiB
# frozenlist             ------------------------------ 141.93 KiB/236.73 KiB
# rich                   ------------------------------ 262.01 KiB/303.37 KiB
# protobuf               ------------------------------ 251.43 KiB/316.67 KiB
# pydantic               ------------------------------ 251.32 KiB/460.92 KiB
# safetensors            ------------------------------ 300.91 KiB/495.27 KiB
# datasets               ------------------------------ 158.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 174.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 270.88 KiB/645.16 KiB
# regex                  ------------------------------ 142.73 KiB/782.35 KiB
# pyyaml                 ------------------------------ 251.35 KiB/788.94 KiB
# setuptools             ------------------------------ 190.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 142.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 206.57 KiB/1.17 MiB
# pygments               ------------------------------ 254.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 142.73 KiB/1.69 MiB
# networkx               ------------------------------ 238.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 237.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 142.72 KiB/2.14 MiB
# pycryptodomex          ------------------------------ 142.79 KiB/2.17 MiB
# tokenizers             ------------------------------ 142.80 KiB/3.12 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠹ Preparing packages... (1/93)
# frozenlist             ------------------------------ 157.93 KiB/236.73 KiB
# rich                   ------------------------------ 278.01 KiB/303.37 KiB
# protobuf               ------------------------------ 255.43 KiB/316.67 KiB
# pydantic               ------------------------------ 255.32 KiB/460.92 KiB
# safetensors            ------------------------------ 316.91 KiB/495.27 KiB
# datasets               ------------------------------ 174.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 190.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 286.88 KiB/645.16 KiB
# regex                  ------------------------------ 142.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 255.35 KiB/788.94 KiB
# setuptools             ------------------------------ 206.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 158.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 206.83 KiB/1.17 MiB
# pygments               ------------------------------ 270.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 142.83 KiB/1.69 MiB
# networkx               ------------------------------ 254.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 253.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 142.82 KiB/2.14 MiB
# pycryptodomex          ------------------------------ 158.79 KiB/2.17 MiB
# tokenizers             ------------------------------ 144.47 KiB/3.12 MiB
# hf-xet                 ------------------------------ 286.57 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠹ Preparing packages... (1/93)
# multiprocess           ------------------------------     0 B/146.76 KiB
# frozenlist             ------------------------------ 173.93 KiB/236.73 KiB
# protobuf               ------------------------------ 271.43 KiB/316.67 KiB
# pydantic               ------------------------------ 271.32 KiB/460.92 KiB
# safetensors            ------------------------------ 331.49 KiB/495.27 KiB
# datasets               ------------------------------ 190.73 KiB/516.58 KiB
# mpmath                 ------------------------------ 206.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 318.88 KiB/645.16 KiB
# regex                  ------------------------------ 158.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 262.62 KiB/788.94 KiB
# setuptools             ------------------------------ 238.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 174.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 222.83 KiB/1.17 MiB
# pygments               ------------------------------ 286.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 158.83 KiB/1.69 MiB
# networkx               ------------------------------ 270.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 269.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 158.82 KiB/2.14 MiB
# pycryptodomex          ------------------------------ 174.79 KiB/2.17 MiB
# tokenizers             ------------------------------ 160.37 KiB/3.12 MiB
# hf-xet                 ------------------------------ 302.57 KiB/4.02 MiB
#    Building tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠹ Preparing packages... (1/93)
# multiprocess           ------------------------------     0 B/146.76 KiB
# frozenlist             ------------------------------ 173.93 KiB/236.73 KiB
# protobuf               ------------------------------ 271.43 KiB/316.67 KiB
# pydantic               ------------------------------ 271.32 KiB/460.92 KiB
# safetensors            ------------------------------ 331.49 KiB/495.27 KiB
# datasets               ------------------------------ 190.73 KiB/516.58 KiB
# mpmath                 ------------------------------ 206.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 318.88 KiB/645.16 KiB
# regex                  ------------------------------ 158.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 278.62 KiB/788.94 KiB
# setuptools             ------------------------------ 238.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 174.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 222.83 KiB/1.17 MiB
# pygments               ------------------------------ 286.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 158.83 KiB/1.69 MiB
# networkx               ------------------------------ 270.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 269.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 158.82 KiB/2.14 MiB
# pycryptodomex          ------------------------------ 174.79 KiB/2.17 MiB
# tokenizers             ------------------------------ 160.37 KiB/3.12 MiB
# hf-xet                 ------------------------------ 302.57 KiB/4.02 MiB
#       Built tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinke
# ⠹ Preparing packages... (1/93)
# jinja2                 ------------------------------ 16.00 KiB/131.74 KiB
# certifi                ------------------------------ 16.00 KiB/132.53 KiB
# nvidia-nvtx            ------------------------------ 26.71 KiB/144.58 KiB
# multiprocess           ------------------------------ 31.78 KiB/146.76 KiB
# frozenlist             ------------------------------ 221.93 KiB/236.73 KiB
# protobuf               ------------------------------ 316.67 KiB/316.67 KiB
# pydantic               ------------------------------ 303.22 KiB/460.92 KiB
# safetensors            ------------------------------ 379.38 KiB/495.27 KiB
# datasets               ------------------------------ 222.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 254.34 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 350.88 KiB/645.16 KiB
# regex                  ------------------------------ 206.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 310.62 KiB/788.94 KiB
# setuptools             ------------------------------ 270.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 206.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 270.72 KiB/1.17 MiB
# pygments               ------------------------------ 334.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 206.83 KiB/1.69 MiB
# networkx               ------------------------------ 318.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 317.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 206.82 KiB/2.14 MiB
# ⠹ Preparing packages... (1/93)
# orjson                 ------------------------------     0 B/130.49 KiB
# jinja2                 ------------------------------ 32.00 KiB/131.74 KiB
# certifi                ------------------------------ 32.00 KiB/132.53 KiB
# nvidia-nvtx            ------------------------------ 42.71 KiB/144.58 KiB
# multiprocess           ------------------------------ 47.78 KiB/146.76 KiB
# frozenlist             ------------------------------ 236.73 KiB/236.73 KiB
# protobuf               ------------------------------ 316.67 KiB/316.67 KiB
# pydantic               ------------------------------ 303.22 KiB/460.92 KiB
# safetensors            ------------------------------ 379.38 KiB/495.27 KiB
# datasets               ------------------------------ 222.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 254.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 366.88 KiB/645.16 KiB
# regex                  ------------------------------ 222.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 319.35 KiB/788.94 KiB
# setuptools             ------------------------------ 286.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 222.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 270.83 KiB/1.17 MiB
# pygments               ------------------------------ 350.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 206.83 KiB/1.69 MiB
# networkx               ------------------------------ 318.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 333.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 222.82 KiB/2.14 MiB
# ⠸ Preparing packages... (9/93)
# urllib3                ------------------------------     0 B/128.50 KiB
# orjson                 ------------------------------ 16.00 KiB/130.49 KiB
# jinja2                 ------------------------------ 48.00 KiB/131.74 KiB
# certifi                ------------------------------ 48.00 KiB/132.53 KiB
# nvidia-nvtx            ------------------------------ 58.61 KiB/144.58 KiB
# multiprocess           ------------------------------ 48.00 KiB/146.76 KiB
# protobuf               ------------------------------ 316.67 KiB/316.67 KiB
# pydantic               ------------------------------ 319.22 KiB/460.92 KiB
# safetensors            ------------------------------ 380.91 KiB/495.27 KiB
# datasets               ------------------------------ 238.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 270.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 382.88 KiB/645.16 KiB
# regex                  ------------------------------ 222.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 335.35 KiB/788.94 KiB
# setuptools             ------------------------------ 302.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 238.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 286.83 KiB/1.17 MiB
# pygments               ------------------------------ 350.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 222.83 KiB/1.69 MiB
# networkx               ------------------------------ 334.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 349.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 222.82 KiB/2.14 MiB
# ⠸ Preparing packages... (9/93)
# anyio                  ------------------------------     0 B/111.67 KiB
# dill                   ------------------------------ 14.81 KiB/117.21 KiB
# urllib3                ------------------------------ 46.80 KiB/128.50 KiB
# orjson                 ------------------------------ 62.69 KiB/130.49 KiB
# jinja2                 ------------------------------ 70.09 KiB/131.74 KiB
# certifi                ------------------------------ 62.28 KiB/132.53 KiB
# nvidia-nvtx            ------------------------------ 77.41 KiB/144.58 KiB
# multiprocess           ------------------------------ 96.00 KiB/146.76 KiB
# protobuf               ------------------------------ 316.67 KiB/316.67 KiB
# pydantic               ------------------------------ 365.46 KiB/460.92 KiB
# safetensors            ------------------------------ 428.91 KiB/495.27 KiB
# datasets               ------------------------------ 286.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 318.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 430.88 KiB/645.16 KiB
# regex                  ------------------------------ 270.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 367.35 KiB/788.94 KiB
# setuptools             ------------------------------ 350.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 286.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 323.69 KiB/1.17 MiB
# pygments               ------------------------------ 398.35 KiB/1.17 MiB
# aiohttp                ------------------------------ 270.83 KiB/1.69 MiB
# networkx               ------------------------------ 366.77 KiB/1.97 MiB
# ⠸ Preparing packages... (9/93)
# anyio                  ------------------------------ 14.78 KiB/111.67 KiB
# dill                   ------------------------------ 30.81 KiB/117.21 KiB
# urllib3                ------------------------------ 46.80 KiB/128.50 KiB
# orjson                 ------------------------------ 78.69 KiB/130.49 KiB
# jinja2                 ------------------------------ 86.09 KiB/131.74 KiB
# certifi                ------------------------------ 78.28 KiB/132.53 KiB
# nvidia-nvtx            ------------------------------ 93.41 KiB/144.58 KiB
# multiprocess           ------------------------------ 96.00 KiB/146.76 KiB
# pydantic               ------------------------------ 381.46 KiB/460.92 KiB
# safetensors            ------------------------------ 444.91 KiB/495.27 KiB
# datasets               ------------------------------ 302.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 318.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 446.88 KiB/645.16 KiB
# regex                  ------------------------------ 286.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 383.35 KiB/788.94 KiB
# setuptools             ------------------------------ 350.80 KiB/1.01 MiB
# tiktoken               ------------------------------ 302.73 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 323.69 KiB/1.17 MiB
# pygments               ------------------------------ 414.35 KiB/1.17 MiB
# aiohttp                ------------------------------ 286.83 KiB/1.69 MiB
# networkx               ------------------------------ 398.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 397.22 KiB/2.00 MiB
# ⠸ Preparing packages... (9/93)
# anyio                  ------------------------------ 62.78 KiB/111.67 KiB
# dill                   ------------------------------ 78.81 KiB/117.21 KiB
# urllib3                ------------------------------ 91.41 KiB/128.50 KiB
# orjson                 ------------------------------ 111.77 KiB/130.49 KiB
# jinja2                 ------------------------------ 126.57 KiB/131.74 KiB
# certifi                ------------------------------ 126.17 KiB/132.53 KiB
# nvidia-nvtx            ------------------------------ 141.41 KiB/144.58 KiB
# multiprocess           ------------------------------ 144.00 KiB/146.76 KiB
# pydantic               ------------------------------ 415.32 KiB/460.92 KiB
# safetensors            ------------------------------ 476.91 KiB/495.27 KiB
# datasets               ------------------------------ 350.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 366.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 478.88 KiB/645.16 KiB
# regex                  ------------------------------ 334.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 422.77 KiB/788.94 KiB
# setuptools             ------------------------------ 392.56 KiB/1.01 MiB
# tiktoken               ------------------------------ 334.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 366.83 KiB/1.17 MiB
# pygments               ------------------------------ 446.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 334.61 KiB/1.69 MiB
# networkx               ------------------------------ 446.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 443.52 KiB/2.00 MiB
# ⠸ Preparing packages... (9/93)
# anyio                  ------------------------------ 62.78 KiB/111.67 KiB
# dill                   ------------------------------ 78.81 KiB/117.21 KiB
# urllib3                ------------------------------ 107.41 KiB/128.50 KiB
# orjson                 ------------------------------ 111.77 KiB/130.49 KiB
# jinja2                 ------------------------------ 126.57 KiB/131.74 KiB
# certifi                ------------------------------ 126.17 KiB/132.53 KiB
# nvidia-nvtx            ------------------------------ 141.41 KiB/144.58 KiB
# pydantic               ------------------------------ 415.32 KiB/460.92 KiB
# safetensors            ------------------------------ 492.91 KiB/495.27 KiB
# datasets               ------------------------------ 350.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 366.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 492.67 KiB/645.16 KiB
# regex                  ------------------------------ 334.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 422.77 KiB/788.94 KiB
# setuptools             ------------------------------ 408.56 KiB/1.01 MiB
# tiktoken               ------------------------------ 334.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 380.82 KiB/1.17 MiB
# pygments               ------------------------------ 446.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 334.61 KiB/1.69 MiB
# networkx               ------------------------------ 446.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 443.52 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 334.72 KiB/2.14 MiB
# ⠸ Preparing packages... (9/93)
# anyio                  ------------------------------ 62.78 KiB/111.67 KiB
# dill                   ------------------------------ 85.62 KiB/117.21 KiB
# urllib3                ------------------------------ 107.41 KiB/128.50 KiB
# orjson                 ------------------------------ 111.77 KiB/130.49 KiB
# jinja2                 ------------------------------ 131.74 KiB/131.74 KiB
# certifi                ------------------------------ 126.28 KiB/132.53 KiB
# pydantic               ------------------------------ 415.32 KiB/460.92 KiB
# safetensors            ------------------------------ 492.91 KiB/495.27 KiB
# datasets               ------------------------------ 350.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 382.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 492.67 KiB/645.16 KiB
# regex                  ------------------------------ 350.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 438.77 KiB/788.94 KiB
# setuptools             ------------------------------ 408.56 KiB/1.01 MiB
# tiktoken               ------------------------------ 334.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 380.82 KiB/1.17 MiB
# pygments               ------------------------------ 462.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 334.83 KiB/1.69 MiB
# networkx               ------------------------------ 462.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 445.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 334.82 KiB/2.14 MiB
# pycryptodomex          ------------------------------ 334.79 KiB/2.17 MiB
# ⠸ Preparing packages... (9/93)
# anyio                  ------------------------------ 62.78 KiB/111.67 KiB
# dill                   ------------------------------ 85.62 KiB/117.21 KiB
# urllib3                ------------------------------ 107.41 KiB/128.50 KiB
# orjson                 ------------------------------ 111.77 KiB/130.49 KiB
# certifi                ------------------------------ 126.28 KiB/132.53 KiB
# pydantic               ------------------------------ 415.32 KiB/460.92 KiB
# safetensors            ------------------------------ 492.91 KiB/495.27 KiB
# datasets               ------------------------------ 350.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 382.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 492.67 KiB/645.16 KiB
# regex                  ------------------------------ 350.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 438.77 KiB/788.94 KiB
# setuptools             ------------------------------ 408.56 KiB/1.01 MiB
# tiktoken               ------------------------------ 334.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 380.82 KiB/1.17 MiB
# pygments               ------------------------------ 462.89 KiB/1.17 MiB
# aiohttp                ------------------------------ 334.83 KiB/1.69 MiB
# networkx               ------------------------------ 462.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 445.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 334.82 KiB/2.14 MiB
# pycryptodomex          ------------------------------ 334.79 KiB/2.17 MiB
# tokenizers             ------------------------------ 318.80 KiB/3.12 MiB
# ⠸ Preparing packages... (9/93)
# click                  ------------------------------     0 B/107.91 KiB
# anyio                  ------------------------------ 93.05 KiB/111.67 KiB
# dill                   ------------------------------ 101.62 KiB/117.21 KiB
# urllib3                ------------------------------ 123.41 KiB/128.50 KiB
# orjson                 ------------------------------ 130.49 KiB/130.49 KiB
# certifi                ------------------------------ 132.53 KiB/132.53 KiB
# pydantic               ------------------------------ 431.32 KiB/460.92 KiB
# datasets               ------------------------------ 366.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 398.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 508.67 KiB/645.16 KiB
# regex                  ------------------------------ 366.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 447.35 KiB/788.94 KiB
# setuptools             ------------------------------ 424.56 KiB/1.01 MiB
# tiktoken               ------------------------------ 350.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 392.56 KiB/1.17 MiB
# pygments               ------------------------------ 474.46 KiB/1.17 MiB
# aiohttp                ------------------------------ 350.83 KiB/1.69 MiB
# networkx               ------------------------------ 478.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 461.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 350.72 KiB/2.14 MiB
# pycryptodomex          ------------------------------ 350.79 KiB/2.17 MiB
# tokenizers             ------------------------------ 328.44 KiB/3.12 MiB
# ⠸ Preparing packages... (9/93)
# click                  ------------------------------     0 B/107.91 KiB
# anyio                  ------------------------------ 93.05 KiB/111.67 KiB
# dill                   ------------------------------ 101.62 KiB/117.21 KiB
# urllib3                ------------------------------ 123.41 KiB/128.50 KiB
# certifi                ------------------------------ 132.53 KiB/132.53 KiB
# pydantic               ------------------------------ 431.32 KiB/460.92 KiB
# datasets               ------------------------------ 366.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 398.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 508.67 KiB/645.16 KiB
# regex                  ------------------------------ 366.84 KiB/782.35 KiB
# pyyaml                 ------------------------------ 447.35 KiB/788.94 KiB
# setuptools             ------------------------------ 424.56 KiB/1.01 MiB
# tiktoken               ------------------------------ 350.83 KiB/1.10 MiB
# nvidia-cufile          ------------------------------ 392.56 KiB/1.17 MiB
# pygments               ------------------------------ 474.46 KiB/1.17 MiB
# aiohttp                ------------------------------ 350.83 KiB/1.69 MiB
# networkx               ------------------------------ 478.77 KiB/1.97 MiB
# pydantic-core          ------------------------------ 461.33 KiB/2.00 MiB
# nvidia-cuda-runtime    ------------------------------ 350.72 KiB/2.14 MiB
# pycryptodomex          ------------------------------ 350.79 KiB/2.17 MiB
# tokenizers             ------------------------------ 328.44 KiB/3.12 MiB
# hf-xet                 ------------------------------ 478.57 KiB/4.02 MiB
# ⠸ Preparing packages... (9/93)
# click                  ------------------------------ 16.00 KiB/107.91 KiB
# anyio                  ------------------------------ 93.05 KiB/111.67 KiB
# dill                   ------------------------------ 101.62 KiB/117.21 KiB
# urllib3                ------------------------------ 123.54 KiB/128.50 KiB
# pydantic               ------------------------------ 447.32 KiB/460.92 KiB
# datasets               ------------------------------ 382.84 KiB/516.58 KiB
# mpmath                 ------------------------------ 398.56 KiB/523.63 KiB
# huggingface-hub        ------------------------------ 508.67 KiB/645.16 KiB
# ...
# nvidia-cublas          ------------------------------ 293.52 MiB/403.53 MiB
# ⠦ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 293.71 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 295.14 MiB/403.53 MiB
# ⠧ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 295.03 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 296.91 MiB/403.53 MiB
# ⠧ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 296.54 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 298.09 MiB/403.53 MiB
# ⠧ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 297.99 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 299.99 MiB/403.53 MiB
# ⠧ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 299.90 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 300.95 MiB/403.53 MiB
# ⠇ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 301.12 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 302.73 MiB/403.53 MiB
# ⠇ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 302.82 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 303.96 MiB/403.53 MiB
# ⠇ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 304.18 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 305.52 MiB/403.53 MiB
# ⠇ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 305.54 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 306.81 MiB/403.53 MiB
# ⠋ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 307.30 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 308.26 MiB/403.53 MiB
# ⠋ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 308.82 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 309.63 MiB/403.53 MiB
# ⠋ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 310.06 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 311.49 MiB/403.53 MiB
# ⠋ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 311.74 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 312.97 MiB/403.53 MiB
# ⠙ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 313.09 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 314.42 MiB/403.53 MiB
# ⠙ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 314.49 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 315.84 MiB/403.53 MiB
# ⠙ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 316.03 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 317.19 MiB/403.53 MiB
# ⠙ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 317.50 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 318.69 MiB/403.53 MiB
# ⠹ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 318.99 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 320.11 MiB/403.53 MiB
# ⠹ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 320.16 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 321.31 MiB/403.53 MiB
# ⠹ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 321.91 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 322.75 MiB/403.53 MiB
# ⠹ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 323.35 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 324.20 MiB/403.53 MiB
# ⠸ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 324.68 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 325.51 MiB/403.53 MiB
# ⠸ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 325.76 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 327.03 MiB/403.53 MiB
# ⠸ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 327.54 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 328.37 MiB/403.53 MiB
# ⠸ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 328.84 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 330.00 MiB/403.53 MiB
# ⠼ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 329.98 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 331.65 MiB/403.53 MiB
# ⠼ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 331.66 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 333.00 MiB/403.53 MiB
# ⠼ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 332.80 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 334.42 MiB/403.53 MiB
# ⠼ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 334.12 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 335.85 MiB/403.53 MiB
# ⠴ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 335.88 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 337.20 MiB/403.53 MiB
# ⠴ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 337.23 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 338.62 MiB/403.53 MiB
# ⠴ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 338.62 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 340.02 MiB/403.53 MiB
# ⠴ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 340.11 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 341.83 MiB/403.53 MiB
# ⠦ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 341.36 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 343.00 MiB/403.53 MiB
# ⠦ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 342.74 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 344.68 MiB/403.53 MiB
# ⠦ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 344.31 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 345.95 MiB/403.53 MiB
# ⠦ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 345.92 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 347.34 MiB/403.53 MiB
# ⠧ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 347.38 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 348.96 MiB/403.53 MiB
# ⠧ Preparing packages... (90/93)
# nvidia-cudnn-cu13      ------------------------------ 348.87 MiB/349.11 MiB
# nvidia-cublas          ------------------------------ 350.29 MiB/403.53 MiB
# ⠧ Preparing packages... (90/93)
# nvidia-cublas          ------------------------------ 351.00 MiB/403.53 MiB
# ⠧ Preparing packages... (90/93)
# nvidia-cublas          ------------------------------ 352.23 MiB/403.53 MiB
# ⠧ Preparing packages... (90/93)
# nvidia-cublas          ------------------------------ 353.70 MiB/403.53 MiB
# ⠇ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 355.36 MiB/403.53 MiB
# ⠇ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 357.23 MiB/403.53 MiB
# ⠇ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 359.11 MiB/403.53 MiB
# ⠇ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 360.63 MiB/403.53 MiB
# ⠋ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 362.03 MiB/403.53 MiB
# ⠋ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 363.63 MiB/403.53 MiB
# ⠋ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 365.57 MiB/403.53 MiB
# ⠋ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 367.30 MiB/403.53 MiB
# ⠙ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 369.03 MiB/403.53 MiB
# ⠙ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 370.38 MiB/403.53 MiB
# ⠙ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 372.29 MiB/403.53 MiB
# ⠙ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 373.85 MiB/403.53 MiB
# ⠹ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 375.76 MiB/403.53 MiB
# ⠹ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 377.29 MiB/403.53 MiB
# ⠹ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 378.67 MiB/403.53 MiB
# ⠹ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 380.76 MiB/403.53 MiB
# ⠸ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 382.17 MiB/403.53 MiB
# ⠸ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 383.99 MiB/403.53 MiB
# ⠸ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 385.54 MiB/403.53 MiB
# ⠸ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 387.07 MiB/403.53 MiB
# ⠼ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 389.00 MiB/403.53 MiB
# ⠼ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 390.38 MiB/403.53 MiB
# ⠼ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 392.42 MiB/403.53 MiB
# ⠼ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 393.79 MiB/403.53 MiB
# ⠴ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 395.42 MiB/403.53 MiB
# ⠴ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 397.29 MiB/403.53 MiB
# ⠴ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 398.93 MiB/403.53 MiB
# ⠴ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 400.63 MiB/403.53 MiB
# ⠦ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 402.08 MiB/403.53 MiB
# ⠦ Preparing packages... (91/93)
# nvidia-cublas          ------------------------------ 403.53 MiB/403.53 MiB
# ⠦ Preparing packages... (91/93)
# ⠦ Preparing packages... (91/93)
# ⠦ Preparing packages... (91/93)
# ⠧ Preparing packages... (92/93)
# ⠧ Preparing packages... (92/93)
# ⠧ Preparing packages... (92/93)
# ⠧ Preparing packages... (92/93)
# ⠇ Preparing packages... (92/93)
# ⠇ Preparing packages... (92/93)
# ⠇ Preparing packages... (92/93)
# ⠇ Preparing packages... (92/93)
# ⠋ Preparing packages... (92/93)
# ⠋ Preparing packages... (92/93)
# ⠋ Preparing packages... (92/93)
# ⠋ Preparing packages... (92/93)
# ⠙ Preparing packages... (92/93)
# ⠙ Preparing packages... (92/93)
# ⠙ Preparing packages... (92/93)
# ⠙ Preparing packages... (92/93)
# ⠹ Preparing packages... (92/93)
# ⠹ Preparing packages... (92/93)
# ⠹ Preparing packages... (92/93)
# ⠹ Preparing packages... (92/93)
# ⠸ Preparing packages... (92/93)
# ⠸ Preparing packages... (92/93)
# ⠸ Preparing packages... (92/93)
# ⠸ Preparing packages... (92/93)
# ⠼ Preparing packages... (92/93)
# ⠼ Preparing packages... (92/93)
# ⠼ Preparing packages... (92/93)
# ⠴ Preparing packages... (92/93)
# ⠴ Preparing packages... (92/93)
# ⠴ Preparing packages... (92/93)
# ⠴ Preparing packages... (92/93)
# ⠴ Preparing packages... (92/93)
# ⠦ Preparing packages... (92/93)
# ⠦ Preparing packages... (92/93)
# ⠦ Preparing packages... (92/93)
# ⠦ Preparing packages... (92/93)
# ⠧ Preparing packages... (92/93)
# ⠧ Preparing packages... (92/93)
# ⠧ Preparing packages... (92/93)
# ⠧ Preparing packages... (92/93)
# ⠇ Preparing packages... (92/93)
# ⠇ Preparing packages... (92/93)
# ⠇ Preparing packages... (92/93)
# ⠇ Preparing packages... (92/93)
# ⠋ Preparing packages... (92/93)
# ⠋ Preparing packages... (92/93)
# ⠋ Preparing packages... (92/93)
# ⠋ Preparing packages... (92/93)
# ⠙ Preparing packages... (92/93)
# ⠙ Preparing packages... (92/93)
# ⠙ Preparing packages... (92/93)
# ⠙ Preparing packages... (92/93)
# ⠹ Preparing packages... (92/93)
# ⠹ Preparing packages... (92/93)
# ⠹ Preparing packages... (92/93)
# ⠹ Preparing packages... (92/93)
# ⠸ Preparing packages... (92/93)
# ⠸ Preparing packages... (92/93)
# ⠸ Preparing packages... (92/93)
# ⠸ Preparing packages... (92/93)
# ⠼ Preparing packages... (92/93)
# ⠼ Preparing packages... (92/93)
# ⠼ Preparing packages... (92/93)
# ⠼ Preparing packages... (92/93)
# ⠴ Preparing packages... (92/93)
# Prepared 93 packages in 36.85s
# Uninstalled 71 packages in 4.48s
# Installed 93 packages in 3.30s
#  ~ aiohappyeyeballs==2.6.1
#  - aiohttp==3.13.3
#  + aiohttp==3.13.5
#  ~ aiosignal==1.4.0
#  ~ annotated-doc==0.0.4
#  ~ annotated-types==0.7.0
#  - anyio==4.12.1
#  + anyio==4.13.0
#  - attrs==25.4.0
#  + attrs==26.1.0
#  ~ blobfile==3.2.0
#  - certifi==2026.1.4
#  + certifi==2026.4.22
#  - charset-normalizer==3.4.4
#  + charset-normalizer==3.4.7
#  + chz==0.4.0
#  - click==8.3.1
#  + click==8.3.3
#  ~ cloudpickle==3.1.2
#  + cuda-bindings==13.2.0
#  + cuda-pathfinder==1.5.4
#  + cuda-toolkit==13.0.2
#  - datasets==4.8.3
#  + datasets==4.8.5
#  ~ dill==0.4.1
#  ~ distro==1.9.0
#  - filelock==3.24.3
#  + filelock==3.29.0
#  ~ frozenlist==1.8.0
#  ~ fsspec==2026.2.0
#  ~ h11==0.16.0
#  ~ h2==4.3.0
#  - hf-xet==1.3.0
#  + hf-xet==1.4.3
#  ~ hpack==4.1.0
#  ~ httpcore==1.0.9
#  ~ httpx==0.28.1
#  - huggingface-hub==1.4.1
#  + huggingface-hub==1.13.0
#  ~ hyperframe==6.1.0
#  - idna==3.11
#  + idna==3.13
#  ~ jinja2==3.1.6
#  - lxml==6.0.2
#  + lxml==6.1.0
#  ~ markdown-it-py==4.0.0
#  ~ markupsafe==3.0.3
#  ~ mdurl==0.1.2
#  ~ mpmath==1.3.0
#  ~ multidict==6.7.1
#  - multiprocess==0.70.16
#  + multiprocess==0.70.19
#  ~ networkx==3.6.1
#  - numpy==2.0.2
#  + numpy==2.4.4
#  + nvidia-cublas==13.1.0.3
#  + nvidia-cuda-cupti==13.0.85
#  + nvidia-cuda-nvrtc==13.0.88
#  + nvidia-cuda-runtime==13.0.96
#  + nvidia-cudnn-cu13==9.19.0.56
#  + nvidia-cufft==12.0.0.61
#  + nvidia-cufile==1.15.1.6
#  + nvidia-curand==10.4.0.35
#  + nvidia-cusolver==12.0.4.66
#  + nvidia-cusparse==12.6.3.3
#  + nvidia-cusparselt-cu13==0.8.0
#  + nvidia-nccl-cu13==2.28.9
#  + nvidia-nvjitlink==13.0.88
#  + nvidia-nvshmem-cu13==3.4.5
#  + nvidia-nvtx==13.0.85
#  - orjson==3.11.7
#  + orjson==3.11.8
#  - packaging==26.0
#  + packaging==26.2
#  - pandas==2.3.3
#  + pandas==3.0.2
#  - pillow==11.3.0
#  + pillow==12.2.0
#  ~ propcache==0.4.1
#  - protobuf==5.29.5
#  + protobuf==7.34.1
#  - pyarrow==23.0.1
#  + pyarrow==24.0.0
#  ~ pycryptodomex==3.23.0
#  - pydantic==2.12.3
#  + pydantic==2.13.3
#  - pydantic-core==2.41.4
#  + pydantic-core==2.46.3
#  - pygments==2.19.2
#  + pygments==2.20.0
#  ~ python-dateutil==2.9.0.post0
#  ~ pyyaml==6.0.3
#  - regex==2025.11.3
#  + regex==2026.4.4
#  - requests==2.32.4
#  + requests==2.33.1
#  - rich==13.9.4
#  + rich==15.0.0
#  ~ safetensors==0.7.0
#  - setuptools==75.2.0
#  + setuptools==81.0.0
#  ~ shellingham==1.5.4
#  ~ six==1.17.0
#  ~ sniffio==1.3.1
#  ~ sympy==1.14.0
#  ~ termcolor==3.3.0
#  ~ tiktoken==0.12.0
#  + tinker==0.18.2
#  + tinker-cookbook==0.3.1.dev23+gdacb835b3 (from git+https://github.com/thinking-machines-lab/tinker-cookbook.git@dacb835b31fb3f7a012851a1bc64c950d0495de3)
#  ~ tokenizers==0.22.2
#  - torch==2.10.0+cpu (from https://download.pytorch.org/whl/cpu/torch-2.10.0%2Bcpu-cp312-cp312-manylinux_2_28_x86_64.whl)
#  + torch==2.11.0
#  ~ tqdm==4.67.3
#  - transformers==5.0.0
#  + transformers==5.5.3
#  + triton==3.6.0
#  - typer==0.24.1
#  + typer==0.25.1
#  ~ typing-extensions==4.15.0
#  ~ typing-inspection==0.4.2
#  - urllib3==2.5.0
#  + urllib3==2.6.3
#  - xxhash==3.6.0
#  + xxhash==3.7.0
#  - yarl==1.22.0
#  + yarl==1.23.0

# %%
# =========================
# 1. INSTALL DEPENDENCIES
# =========================
# Run in terminal / notebook cell
# !uv pip install --no-cache-dir --force-reinstall "tinker-cookbook @ git+https://github.com/thinking-machines-lab/tinker-cookbook.git@nightly"

# =========================
# 2. IMPORTS
# =========================
import torch
import shutil
import tinker_cookbook.weights._adapter as A
from tinker_cookbook import weights

# =========================
# 3. CONFIGURATION
# =========================
FORCED_FUSED_RANK = 32


# =========================
# 4. HELPER FUNCTION
# =========================
def _compress_lora_pair_to_rank(B: torch.Tensor, A_mat: torch.Tensor, rank: int):
    # Compute delta = B @ A
    delta = B.float() @ A_mat.float()

    # Perform SVD decomposition
    U, S, Vh = torch.linalg.svd(delta, full_matrices=False)

    # Truncate to desired rank
    U = U[:, :rank]
    S = S[:rank]
    Vh = Vh[:rank, :]

    # Reconstruct LoRA matrices
    sroot = torch.sqrt(S)
    B_new = U * sroot.unsqueeze(0)
    A_new = sroot.unsqueeze(1) * Vh

    return B_new.to(B.dtype).contiguous(), A_new.to(A_mat.dtype).contiguous()


# =========================
# 5. PATCH FUNCTION
# =========================
def patched_merge_fused_projections(
    fused_model_key: str,
    adapter_layer_prefix: str,
    components,
    model_state_shapes,
    peft_weights,
    target_modules,
    profile,
) -> int:

    fused_out_dim = model_state_shapes[fused_model_key][0]
    fused_target_name = fused_model_key.removesuffix(".weight").rsplit(".", 1)[-1]

    # Find component order
    component_order = None
    for target, comps in profile.fused_projection_map:
        if target == fused_target_name:
            component_order = comps
            break

    assert component_order is not None, "Component order not found"

    comp_by_name = {name: (lora_A, lora_B) for name, lora_A, lora_B in components}

    lora_A_parts = []
    comp_slices = []
    merged_rank = 0
    row_offset = 0

    # Merge components
    for comp_name in component_order:
        if comp_name not in comp_by_name:
            raise RuntimeError(f"Missing component {comp_name}")

        lora_A, lora_B = comp_by_name[comp_name]

        r = lora_A.shape[0]
        out_dim = lora_B.shape[0]

        lora_A_parts.append(lora_A)
        comp_slices.append((row_offset, row_offset + out_dim, r))

        row_offset += out_dim
        merged_rank += r

    merged_lora_A = torch.cat(lora_A_parts, dim=0)

    merged_lora_B = torch.zeros(
        fused_out_dim,
        merged_rank,
        dtype=merged_lora_A.dtype,
        device=merged_lora_A.device,
    )

    # Fill B matrix
    rank_offset = 0
    for i, (row_start, row_end, r) in enumerate(comp_slices):
        _, lora_B = comp_by_name[component_order[i]]
        merged_lora_B[row_start:row_end, rank_offset:rank_offset + r] = lora_B
        rank_offset += r

    # Compress to rank 32 if needed
    final_rank = merged_rank
    if merged_rank > FORCED_FUSED_RANK:
        merged_lora_B, merged_lora_A = _compress_lora_pair_to_rank(
            merged_lora_B,
            merged_lora_A,
            FORCED_FUSED_RANK
        )
        final_rank = FORCED_FUSED_RANK

    # Save result
    peft_target_key = f"{adapter_layer_prefix}.{fused_target_name}.weight"
    A._add_peft_weight(
        peft_target_key,
        merged_lora_A,
        merged_lora_B,
        peft_weights,
        target_modules
    )

    return final_rank


# =========================
# 6. APPLY PATCH
# =========================
A._merge_fused_projections = patched_merge_fused_projections
print("Patched function:", A._merge_fused_projections.__name__)


# =========================
# 7. BUILD LORA ADAPTER
# =========================
weights.build_lora_adapter(
    base_model="nvidia/NVIDIA-Nemotron-3-Nano-30B-A3B-BF16",
    adapter_path="/kaggle/input/models/huikang/nemotron-adapter/transformers/default/20",
    output_path="/kaggle/working/nemotron-adapter-ready-to-submit",
)


# =========================
# 8. ZIP OUTPUT
# =========================
shutil.make_archive(
    '/kaggle/working/submission',
    'zip',
    '/kaggle/working/nemotron-adapter-ready-to-submit'
)

print("ZIP archive successfully created!")
# Out:
# Patched function: patched_merge_fused_projections
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 35 files:   0%|          | 0/35 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# MoE expert LoRA serving for nemotron models is experimental in vLLM and not yet supported in SGLang. The adapter will be produced but may not work with all serving configurations.
# ZIP archive successfully created!
